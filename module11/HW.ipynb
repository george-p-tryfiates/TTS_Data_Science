# %% [markdown]
# ### HW

# %% [markdown]
# Exercise 1: Read Total profit of all months and show it using a line plot
#
# Total profit data provided for each month. Generated line plot must include the following properties:
#
#     X label name = Month Number
#     Y label name = Total profit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
df = pd.read_csv('company_sales.csv')
df.total_profit
fig = plt.figure()
ax = plt.axes()
ax.plot(df.month_number,data.total_profit)
plt.xlabel("Month")
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# Exercise Question 2: Get Total profit of all months and show line plot with the following Style properties
#
# Generated line plot must include following Style properties:
#
#     Line Style dotted and Line-color should be red
#     Show legend at the lower right location.
#     X label name = Month Number
#     Y label name = Sold units number
#     Add a circle marker.
#     Line marker color as read
#     Line width should be 3

# %%
fig = plt.figure()
ax = plt.axes(label = "2")
ax.plot(df.month_number,data.total_profit, ":r", marker = "o", linewidth = 3, label = "Total Profit")
plt.xlabel("Month Number")
plt.ylabel("Sold Units Number")
leg = ax.legend(loc='lower right')

# %% [markdown]
# Exercise Question 3: Read all product sales data and show it using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
fig = plt.figure()
ax = plt.axes(label = "2")
ax.plot(df.month_number, data['facecream'], "r", marker = "o", linewidth = 3, label = 'facecream')
ax.plot(df.month_number, data['facewash'], "b", marker = "o", linewidth = 3, label = "facewash")
ax.plot(df.month_number, data['toothpaste'], "c", marker = "o", linewidth = 3, label = "toothpaste")
ax.plot(df.month_number, data['bathingsoap'], "d:", marker = "o", linewidth = 3, label = "bathingsoap")
ax.plot(df.month_number, data['shampoo'], "p:", marker = "o", linewidth = 3, label = "shampoo")
ax.plot(df.month_number, data['moisturizer'], "m:", marker = "o", linewidth = 3, label = "moisturizer")

plt.xlabel("Month Number")
plt.ylabel("Sold Units Number")
leg = ax.legend(loc='upper left')

# %% [markdown]
# Exercise Question 4: Read toothpaste sales data of
#     each month and show it using a scatter plot
#
#
# Also, add a grid in the plot. gridline style should “–“.

# %%
plt.plot(data.month_number, data.toothpaste, 'o', color = 'blue');
plt.title('Toothpaste Sales')
# Out:
# Text(0.5, 1.0, 'Toothpaste Sales')

# %%
Exercise Question 5: Read face cream and face wash product sales 
    data and show it using the bar chart

The bar chart should display the number of units sold 
per month for each product. Add a separate bar for each 
product in the same chart.

# %%
fig = plt.figure()
ax = plt.axes(label = "2")
ax.bar(df.month_number, data['facecream'], width = 0.25)
ax.bar(df.month_number + 0.25, data.facewash, width = 0.25 )

plt.xlabel("Month Number")
plt.ylabel("Units Sold")
leg = ax.legend(loc='upper left')
# Out:
# No handles with labels found to put in legend.
